# %%
import pandas as pd
import numpy as np
import re
import string
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
data=pd.read_csv("Reviews.csv")
data
# Out:
#             Id   ProductId          UserId                      ProfileName  \
# 0            1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1            2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2            3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3            4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4            5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# ...        ...         ...             ...                              ...
# 568449  568450  B001EO7N10  A28KG5XORO54AY                 Lettie D. Carter
# 568450  568451  B003S1WTCU  A3I8AFVPEE8KI5                        R. Sawyer
# 568451  568452  B004I613EE  A121AA1GQV751Z                    pksd "pk_007"
# 568452  568453  B004I613EE   A3IBEVCTXKNOH          Kathy A. Welch "katwel"
# 568453  568454  B001LR2CU2  A3LGQPJCZVL9UC                         srfell17
#
# ...

# %%
df=data

# %%
unique_scores = df['Score'].unique()
print(unique_scores)
# Out:
# [5 1 4 2 3]

# %%
unique = df['HelpfulnessDenominator'].unique()
print(unique)
# Out:
# [  1   0   3   4   2   5  19  13   9   7  15   8   6  10  47  17  14  27
#   12  11  21  31  18  23 168  46  30 133  16  36  25  26  24  22  29  20
#   64 216  33 112 108  51  37  39  89  35  43  42  74  49  34  28  53  96
#   58  41  65 130 100  84  38  40  32  48 219 155  83  85  72  56  63 128
#   79  76  55  68  66  44  94  59 117 188 134  92  57  71  98  90  45 135
#  170  77  52 123  50  93  88 122 212 192 120 401 209  95  86  99  73  60
#  124  54  61  70 180  91  81 138 163 307 270 151  78  62 119 139 137 215
#  539 305 562 477 235  87  69 298  75  82 103 156 110 144  80  67 127 162
#  181 356 245 462 174 111 182 143 179 159 101 171  97 249 384 187 121 263
#  131 165 416 106 878 536 238 109 923 115 150 371 105 154 125 149 569 360
#  222 593 185 486 126 114 140 452 323 365 197 284 488 383 152 118 436 176
#  132 544 184 274 240 229 158 415 296 172 496 160 248 220 178 147 107 286
#  190 102 214 164 186 230 104 282 145 200 322 228 191 256 251 195 113 815]

# %%
df.shape
# Out:
# (568454, 10)

# %%
df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %%
df = df.drop(columns=['Id','UserId','ProfileName'],axis=1)

# %%
df.isnull().sum()
# Out:
# ProductId                  0
# HelpfulnessNumerator       0
# HelpfulnessDenominator     0
# Score                      0
# Time                       0
# Summary                   27
# Text                       0
# dtype: int64

# %%
df=df.dropna()

# %%
df.duplicated().sum()
# Out:
# 282

# %%
df=df.drop_duplicates()

# %% [markdown]
# #Feature Eng

# %%
df['Review'] = df['Summary'] + ' ' + df['Text']

# %%
df = df.drop(columns=['Text','Summary'],axis=1)
df.head()
# Out:
#     ProductId  HelpfulnessNumerator  HelpfulnessDenominator  Score  \
# 0  B001E4KFG0                     1                       1      5
# 1  B00813GRG4                     0                       0      1
# 2  B000LQOCH0                     1                       1      4
# 3  B000UA0QIQ                     3                       3      2
# 4  B006K2ZZ7K                     0                       0      5
#
#          Time                                             Review
# 0  1303862400  Good Quality Dog Food I have bought several of...
# 1  1346976000  Not as Advertised Product arrived labeled as J...
# 2  1219017600  "Delight" says it all This is a confection tha...
# 3  1307923200  Cough Medicine If you are looking for the secr...
# 4  1350777600  Great taffy Great taffy at a great price.  The...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 568145 entries, 0 to 568453
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   ProductId               568145 non-null  object
#  1   HelpfulnessNumerator    568145 non-null  int64
#  2   HelpfulnessDenominator  568145 non-null  int64
#  3   Score                   568145 non-null  int64
#  4   Time                    568145 non-null  int64
#  5   Review                  568145 non-null  object
# dtypes: int64(4), object(2)
# memory usage: 30.3+ MB

# %%
df['Helpness_Score']=np.where(df['HelpfulnessDenominator']>0,df['HelpfulnessNumerator']/df['HelpfulnessDenominator'],-1)
df.head(20)
# Out:
#      ProductId  HelpfulnessNumerator  HelpfulnessDenominator  Score  \
# 0   B001E4KFG0                     1                       1      5
# 1   B00813GRG4                     0                       0      1
# 2   B000LQOCH0                     1                       1      4
# 3   B000UA0QIQ                     3                       3      2
# 4   B006K2ZZ7K                     0                       0      5
# 5   B006K2ZZ7K                     0                       0      4
# 6   B006K2ZZ7K                     0                       0      5
# 7   B006K2ZZ7K                     0                       0      5
# 8   B000E7L2R4                     1                       1      5
# 9   B00171APVA                     0                       0      5
# 10  B0001PB9FE                     1                       1      5
# 11  B0009XLVG0                     4                       4      5
# 12  B0009XLVG0                     1                       1      1
# ...

# %%
df.drop(['HelpfulnessDenominator','HelpfulnessNumerator'],axis=1,inplace=True)
df.head()
# Out:
#     ProductId  Score        Time  \
# 0  B001E4KFG0      5  1303862400
# 1  B00813GRG4      1  1346976000
# 2  B000LQOCH0      4  1219017600
# 3  B000UA0QIQ      2  1307923200
# 4  B006K2ZZ7K      5  1350777600
#
#                                               Review  Helpness_Score
# 0  Good Quality Dog Food I have bought several of...             1.0
# 1  Not as Advertised Product arrived labeled as J...            -1.0
# 2  "Delight" says it all This is a confection tha...             1.0
# 3  Cough Medicine If you are looking for the secr...             1.0
# 4  Great taffy Great taffy at a great price.  The...            -1.0

# %%
from datetime import datetime
df['Time_ymd']=df['Time'].apply(lambda col: datetime.utcfromtimestamp(int(col)).strftime('%Y-%m-%d'))

df.drop(['Time'] ,axis=1, inplace=True)
df.head()
# Out:
#     ProductId  Score                                             Review  \
# 0  B001E4KFG0      5  Good Quality Dog Food I have bought several of...
# 1  B00813GRG4      1  Not as Advertised Product arrived labeled as J...
# 2  B000LQOCH0      4  "Delight" says it all This is a confection tha...
# 3  B000UA0QIQ      2  Cough Medicine If you are looking for the secr...
# 4  B006K2ZZ7K      5  Great taffy Great taffy at a great price.  The...
#
#    Helpness_Score    Time_ymd
# 0             1.0  2011-04-27
# 1            -1.0  2012-09-07
# 2             1.0  2008-08-18
# 3             1.0  2011-06-13
# 4            -1.0  2012-10-21

# %% [markdown]
# #Text Preprocessing

# %% [markdown]
# #Case Folding , stopwords , punctuation

# %%
punctuation =  set(string.punctuation)
stop_words = set(stopwords.words("english"))
stop_words.update(["br", "href","amazon","product","counter"])

# %%
def Clean_Text(review):
  x = review
  x = re.sub(r'https?:\S', '', x)
  x = re.sub(r'{link}', '', x)
  x = re.sub(r'@[\w]', '', x)
  x = re.sub(r'[^A-Za-z0-9]+', ' ', x)
  x = re.sub(r'\b[0-9]+\b', '', x)
  x = re.sub(r'&[a-z]+', '', x)
  x = ''.join(w for w in x if w not in punctuation)
  x = x.replace('[^a-zA-Z#]',' ')

  x = [w.lower() for w in x.split() if w.lower() not in stop_words]
  x = [w for w in x if len(w) > 3]
  return x

# %%
df['Clean_Text'] = df['Review'].apply(lambda x: Clean_Text(x) if isinstance(x, str) else '')

# %%
df.head(20)
# Out:
#      ProductId  Score                                             Review  \
# 0   B001E4KFG0      5  Good Quality Dog Food I have bought several of...
# 1   B00813GRG4      1  Not as Advertised Product arrived labeled as J...
# 2   B000LQOCH0      4  "Delight" says it all This is a confection tha...
# 3   B000UA0QIQ      2  Cough Medicine If you are looking for the secr...
# 4   B006K2ZZ7K      5  Great taffy Great taffy at a great price.  The...
# 5   B006K2ZZ7K      4  Nice Taffy I got a wild hair for taffy and ord...
# 6   B006K2ZZ7K      5  Great!  Just as good as the expensive brands! ...
# 7   B006K2ZZ7K      5  Wonderful, tasty taffy This taffy is so good. ...
# 8   B000E7L2R4      5  Yay Barley Right now I'm mostly just sprouting...
# 9   B00171APVA      5  Healthy Dog Food This is a very healthy dog fo...
# 10  B0001PB9FE      5  The Best Hot Sauce in the World I don't know i...
# 11  B0009XLVG0      5  My cats LOVE this "diet" food better than thei...
# ...

# %%
# Convert lists of words into strings
df['Clean_Text'] = df['Clean_Text'].apply(lambda x: ' '.join(x))
print(df)
# Out:
#          ProductId  Score                                             Review  \
# 0       B001E4KFG0      5  Good Quality Dog Food I have bought several of...
# 1       B00813GRG4      1  Not as Advertised Product arrived labeled as J...
# 2       B000LQOCH0      4  "Delight" says it all This is a confection tha...
# 3       B000UA0QIQ      2  Cough Medicine If you are looking for the secr...
# 4       B006K2ZZ7K      5  Great taffy Great taffy at a great price.  The...
# ...            ...    ...                                                ...
# 568449  B001EO7N10      5  Will not do without Great for sesame chicken.....
# 568450  B003S1WTCU      2  disappointed I'm disappointed with the flavor....
# 568451  B004I613EE      5  Perfect for our maltipoo These stars are small...
# 568452  B004I613EE      5  Favorite Training and reward treat These are t...
# 568453  B001LR2CU2      5  Great Honey I am very satisfied ,product is as...
#
#         Helpness_Score    Time_ymd  \
# ...

# %% [markdown]
# # Part Of Speech

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
pos_tags = [nltk.pos_tag(nltk.word_tokenize(review))for review in df['Clean_Text']]
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# # Lemmatization

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
from nltk.corpus import wordnet as wn
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
import pandas as pd

# Initialize variables and objects
lemmatizer = WordNetLemmatizer()

# A dictionary mapping part-of-speech tags to WordNet part-of-speech constants.
tag_dict = {"J": wn.ADJ,
            "N": wn.NOUN,
            "V": wn.VERB,
            "R": wn.ADV}

# Maps a part-of-speech tag (e.g., 'NN') to its WordNet equivalent.
def mapToWordEq(tag):
    return tag_dict.get(tag[0].upper(), None)

# Function to lemmatize a word given its tuple (word, pos_tag)
def lemmatize_tupla_word_postag(tupla):
    tag = mapToWordEq(tupla[1])
    return lemmatizer.lemmatize(tupla[0], tag) if tag is not None else tupla[0]

# Function to perform bag of words processing on a sentence
def bag_of_words(sentence):
    original_words = word_tokenize(sentence)
    tagged_words = nltk.pos_tag(original_words)
    lemmatized_words = [lemmatize_tupla_word_postag(ow) for ow in tagged_words]

    return lemmatized_words

# %%
df.columns
# Out:
# Index(['ProductId', 'Score', 'Review', 'Helpness_Score', 'Time_ymd',
#        'Clean_Text'],
#       dtype='object')

# %%
# Process each review in the DataFrame
processed_reviews = []
for index, row in df.iterrows():
    review_text = row['Clean_Text']

    cleaned_words = bag_of_words(review_text)

    # Append the cleaned words and 'Liked' value to the list
    processed_reviews.append({'Clean_Text': cleaned_words, 'ProductId': row['ProductId'], 'Score': row['Score'], 'Review': row['Review'], 'Helpness_Score': row['Helpness_Score']})

# Create a new DataFrame from the processed reviews
Review_data_Processed = pd.DataFrame(processed_reviews)

# Display the processed DataFrame
print(Review_data_Processed)
# Out:
#                                                Clean_Text   ProductId  Score  \
# 0       [good, quality, food, buy, several, vitality, ...  B001E4KFG0      5
# 1       [advertise, arrive, labeled, jumbo, salt, pean...  B00813GRG4      1
# 2       [delight, say, confection, around, century, li...  B000LQOCH0      4
# 3       [cough, medicine, look, secret, ingredient, ro...  B000UA0QIQ      2
# 4       [great, taffy, great, taffy, great, price, wid...  B006K2ZZ7K      5
# ...                                                   ...         ...    ...
# 568140  [without, great, sesame, chicken, good, good, ...  B001EO7N10      5
# 568141  [disappoint, disappointed, flavor, chocolate, ...  B003S1WTCU      2
# 568142  [perfect, maltipoo, star, small, give, train, ...  B004I613EE      5
# 568143  [favorite, train, reward, treat, best, treat, ...  B004I613EE      5
# 568144  [great, honey, satisfy, advertised, cereal, vi...  B001LR2CU2      5
#
# ...

# %%
df.dropna(inplace=True)
print(df.isnull().sum())
# Out:
# ProductId         0
# Score             0
# Review            0
# Helpness_Score    0
# Time_ymd          0
# Clean_Text        0
# dtype: int64
# ProductId         0
# Score             0
# Review            0
# Helpness_Score    0
# Time_ymd          0
# Clean_Text        0
# dtype: int64

# %%
df
# Out:
#          ProductId  Score                                             Review  \
# 0       B001E4KFG0      5  Good Quality Dog Food I have bought several of...
# 1       B00813GRG4      1  Not as Advertised Product arrived labeled as J...
# 2       B000LQOCH0      4  "Delight" says it all This is a confection tha...
# 3       B000UA0QIQ      2  Cough Medicine If you are looking for the secr...
# 4       B006K2ZZ7K      5  Great taffy Great taffy at a great price.  The...
# ...            ...    ...                                                ...
# 568449  B001EO7N10      5  Will not do without Great for sesame chicken.....
# 568450  B003S1WTCU      2  disappointed I'm disappointed with the flavor....
# 568451  B004I613EE      5  Perfect for our maltipoo These stars are small...
# 568452  B004I613EE      5  Favorite Training and reward treat These are t...
# 568453  B001LR2CU2      5  Great Honey I am very satisfied ,product is as...
#
#         Helpness_Score    Time_ymd  \
# ...

# %%
def score_classification(score):
    if score > 3:
        return 2
    elif score == 3:
        return 1
    else:
        return 0

# %%
df['SentimentManiual']=df['Score'].apply(lambda x:score_classification(x))
df.head()
# Out:
#     ProductId  Score                                             Review  \
# 0  B001E4KFG0      5  Good Quality Dog Food I have bought several of...
# 1  B00813GRG4      1  Not as Advertised Product arrived labeled as J...
# 2  B000LQOCH0      4  "Delight" says it all This is a confection tha...
# 3  B000UA0QIQ      2  Cough Medicine If you are looking for the secr...
# 4  B006K2ZZ7K      5  Great taffy Great taffy at a great price.  The...
#
#    Helpness_Score    Time_ymd  \
# 0             1.0  2011-04-27
# 1            -1.0  2012-09-07
# 2             1.0  2008-08-18
# 3             1.0  2011-06-13
# 4            -1.0  2012-10-21
#
#                                           Clean_Text  SentimentManiual
# 0  good quality food bought several vitality cann...                 2
# 1  advertised arrived labeled jumbo salted peanut...                 0
# 2  delight says confection around centuries light...                 2
# ...

# %%
df['SentimentManiual'].value_counts()
# Out:
# 2    443562
# 0     81971
# 1     42612
# Name: SentimentManiual, dtype: int64

# %%
df.shape
# Out:
# (568145, 7)

# %% [markdown]
# #Sentiment Analysis

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
analyzer = SentimentIntensityAnalyzer()

def get_sentiment(text):
    scores = analyzer.polarity_scores(text)

    if scores['compound'] >= 0.05 :
        sentiment = 2
    elif scores['compound'] <= -0.05:
        sentiment = 0
    else:
        sentiment = 1

    return sentiment


df['sentimentPolarity'] = df['Clean_Text'].apply(get_sentiment)

df
# Out:
#          ProductId  Score                                             Review  \
# 0       B001E4KFG0      5  Good Quality Dog Food I have bought several of...
# 1       B00813GRG4      1  Not as Advertised Product arrived labeled as J...
# 2       B000LQOCH0      4  "Delight" says it all This is a confection tha...
# 3       B000UA0QIQ      2  Cough Medicine If you are looking for the secr...
# 4       B006K2ZZ7K      5  Great taffy Great taffy at a great price.  The...
# ...            ...    ...                                                ...
# 568449  B001EO7N10      5  Will not do without Great for sesame chicken.....
# 568450  B003S1WTCU      2  disappointed I'm disappointed with the flavor....
# 568451  B004I613EE      5  Perfect for our maltipoo These stars are small...
# 568452  B004I613EE      5  Favorite Training and reward treat These are t...
# 568453  B001LR2CU2      5  Great Honey I am very satisfied ,product is as...
#
#         Helpness_Score    Time_ymd  \
# ...

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(df['SentimentManiual'], df['sentimentPolarity']))
# Out:
# [[ 24158   3845  53968]
#  [  3490   1219  37903]
#  [  7610   3333 432619]]

# %%
from sklearn.metrics import classification_report, accuracy_score

accuracy = accuracy_score(df['SentimentManiual'], df['sentimentPolarity'])

print("Accuracy:", accuracy)

print(classification_report(df['SentimentManiual'], df['sentimentPolarity']))
# Out:
# Accuracy: 0.80612519691276
#               precision    recall  f1-score   support
#
#            0       0.69      0.29      0.41     81971
#            1       0.15      0.03      0.05     42612
#            2       0.82      0.98      0.89    443562
#
#     accuracy                           0.81    568145
#    macro avg       0.55      0.43      0.45    568145
# weighted avg       0.75      0.81      0.76    568145

# %%
def eqNeg (cmp):
  return (cmp-(-1))*((2-1)/(-0.05+1))+1

def eqPos(cmp):
  return (cmp-(0.05))*((5-4)/(1-(0.05)))+4

# %%
analyzer = SentimentIntensityAnalyzer()

def get_sentiment(text):
    scores = analyzer.polarity_scores(text)

    if scores['compound'] >= 0.05 :
        sentiment = round(eqPos(scores['compound']))
    elif scores['compound'] <= -0.05:
        sentiment = round(eqNeg(scores['compound']))
    else:
        sentiment = 3

    return sentiment

df['scores']= df['Clean_Text'].apply(analyzer.polarity_scores)

df['sentiment'] = df['Clean_Text'].apply(get_sentiment)

df
# Out:
#          ProductId  Score                                             Review  \
# 0       B001E4KFG0      5  Good Quality Dog Food I have bought several of...
# 1       B00813GRG4      1  Not as Advertised Product arrived labeled as J...
# 2       B000LQOCH0      4  "Delight" says it all This is a confection tha...
# 3       B000UA0QIQ      2  Cough Medicine If you are looking for the secr...
# 4       B006K2ZZ7K      5  Great taffy Great taffy at a great price.  The...
# ...            ...    ...                                                ...
# 568449  B001EO7N10      5  Will not do without Great for sesame chicken.....
# 568450  B003S1WTCU      2  disappointed I'm disappointed with the flavor....
# 568451  B004I613EE      5  Perfect for our maltipoo These stars are small...
# 568452  B004I613EE      5  Favorite Training and reward treat These are t...
# 568453  B001LR2CU2      5  Great Honey I am very satisfied ,product is as...
#
#         Helpness_Score    Time_ymd  \
# ...

# %%
df.rename(columns={'sentiment': 'sentimentScore'}, inplace=True)
df = df.drop(columns=['scores'],axis=1)

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(df['Score'], df['sentimentScore']))
# Out:
# [[ 10938   7978   2642   9238  21435]
#  [  2364   2878   1203   4692  18603]
#  [  1241   2249   1219   5034  32869]
#  [   715   1295    824   4523  73270]
#  [  1821   3779   2509  13655 341171]]

# %%
from sklearn.metrics import classification_report, accuracy_score
accuracy = accuracy_score(df['Score'], df['sentimentScore'])
print("Accuracy:", accuracy)

print(classification_report(df['Score'], df['sentimentScore']))
# Out:
# Accuracy: 0.634924183087064
#               precision    recall  f1-score   support
#
#            1       0.64      0.21      0.32     52231
#            2       0.16      0.10      0.12     29740
#            3       0.15      0.03      0.05     42612
#            4       0.12      0.06      0.08     80627
#            5       0.70      0.94      0.80    362935
#
#     accuracy                           0.63    568145
#    macro avg       0.35      0.27      0.27    568145
# weighted avg       0.54      0.63      0.56    568145

# %%
final=df
final
# Out:
#          ProductId  Score                                             Review  \
# 0       B001E4KFG0      5  Good Quality Dog Food I have bought several of...
# 1       B00813GRG4      1  Not as Advertised Product arrived labeled as J...
# 2       B000LQOCH0      4  "Delight" says it all This is a confection tha...
# 3       B000UA0QIQ      2  Cough Medicine If you are looking for the secr...
# 4       B006K2ZZ7K      5  Great taffy Great taffy at a great price.  The...
# ...            ...    ...                                                ...
# 568449  B001EO7N10      5  Will not do without Great for sesame chicken.....
# 568450  B003S1WTCU      2  disappointed I'm disappointed with the flavor....
# 568451  B004I613EE      5  Perfect for our maltipoo These stars are small...
# 568452  B004I613EE      5  Favorite Training and reward treat These are t...
# 568453  B001LR2CU2      5  Great Honey I am very satisfied ,product is as...
#
#         Helpness_Score    Time_ymd  \
# ...

# %%
final.to_csv("Cleaned_Data.csv")
